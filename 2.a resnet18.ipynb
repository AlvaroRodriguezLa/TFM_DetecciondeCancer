# %%
import os
import random
import shutil
import copy
import time
import torch
import torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from sklearn.utils.class_weight import compute_class_weight
from glob import glob
from skimage.io import imread
from os import listdir
#import tensorflow as tf
# Out:
# C:\Users\alvaro.rlanceta\AppData\Local\anaconda3\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
# Ruta de la carpeta principal
main_folder = "\\datasetsClases"

# ResNet input size
input_size = (224, 224)

# %%
# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")
# Out:
# Initializing Datasets and Dataloaders...

# %%
# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(main_folder, x), data_transforms[x]) for x in ['train', 'val', 'test']}

# Generamos los índices para el subconjunto
subset_indices_train = torch.randperm(len(image_datasets['train']))[:int(0.3*len(image_datasets['train']))]
subset_indices_val = torch.randperm(len(image_datasets['val']))[:int(0.3*len(image_datasets['val']))]
subset_indices_test = torch.randperm(len(image_datasets['test']))[:int(0.3*len(image_datasets['test']))]

# Creamos los subconjuntos
train_data_subset = torch.utils.data.Subset(image_datasets['train'], subset_indices_train)
val_data_subset = torch.utils.data.Subset(image_datasets['val'], subset_indices_val)
test_data_subset = torch.utils.data.Subset(image_datasets['test'], subset_indices_test)

# Create training and validation dataloaders
dataloaders_dict = {
    'train': torch.utils.data.DataLoader(train_data_subset, batch_size=batch_size, shuffle=True, num_workers=4),
    'val': torch.utils.data.DataLoader(val_data_subset, batch_size=batch_size, shuffle=True, num_workers=4),
    'test': torch.utils.data.DataLoader(test_data_subset, batch_size=batch_size, shuffle=True, num_workers=4),    
}

# %%
from collections import Counter

# Función para contar las instancias de cada clase en un subconjunto de datos
def count_classes(data_subset):
    # Obtenemos las etiquetas de todas las instancias en el subconjunto
    labels = [data_subset.dataset.targets[i] for i in data_subset.indices]
    # Contamos las ocurrencias de cada etiqueta
    class_counts = Counter(labels)
    return class_counts

# Contamos las clases en cada subconjunto
train_class_count = count_classes(train_data_subset)
val_class_count = count_classes(val_data_subset)
test_class_count = count_classes(test_data_subset)

print("Conteo de clases en el subconjunto de entrenamiento:", train_class_count)
print("Conteo de clases en el subconjunto de validación:", val_class_count)
print("Conteo de clases en el subconjunto de prueba:", test_class_count)
# Out:
# Conteo de clases en el subconjunto de entrenamiento: Counter({0: 47689, 1: 18923})
# Conteo de clases en el subconjunto de validación: Counter({0: 5947, 1: 2379})
# Conteo de clases en el subconjunto de prueba: Counter({0: 5943, 1: 2384})

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %%
def initialize_model(num_classes):
    # Resnet18 
    model = models.resnet18()
    
    model.fc = nn.Linear(512, num_classes)
    
    input_size = 224
        
    return model, input_size

# %%
# Number of classes in the dataset
num_classes = 2

# Initialize the model
model, input_size = initialize_model(num_classes)

# Print the model we just instantiated
print(model)

# Send the model to GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 20

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# %%
# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.4139 Acc: 0.8200
# val Loss: 0.3321 Acc: 0.8591
#
# Epoch 1/19
# ----------
# train Loss: 0.3755 Acc: 0.8374
# val Loss: 0.3240 Acc: 0.8620
#
# Epoch 2/19
# ----------
# train Loss: 0.3640 Acc: 0.8437
# val Loss: 0.3218 Acc: 0.8634
#
# Epoch 3/19
# ----------
# train Loss: 0.3571 Acc: 0.8459
# val Loss: 0.3166 Acc: 0.8685
#
# Epoch 4/19
# ----------
# train Loss: 0.3495 Acc: 0.8499
# val Loss: 0.3194 Acc: 0.8637
#
# Epoch 5/19
# ----------
# train Loss: 0.3440 Acc: 0.8531
# val Loss: 0.3137 Acc: 0.8680
#
# Epoch 6/19
# ----------
# train Loss: 0.3403 Acc: 0.8547
# val Loss: 0.3061 Acc: 0.8704
#
# Epoch 7/19
# ----------
# train Loss: 0.3341 Acc: 0.8574
# val Loss: 0.3079 Acc: 0.8711
#
# Epoch 8/19
# ----------
# train Loss: 0.3307 Acc: 0.8590
# val Loss: 0.3063 Acc: 0.8759
#
# Epoch 9/19
# ----------
# train Loss: 0.3253 Acc: 0.8608
# val Loss: 0.2932 Acc: 0.8805
#
# Epoch 10/19
# ----------
# train Loss: 0.3206 Acc: 0.8640
# val Loss: 0.2842 Acc: 0.8853
#
# Epoch 11/19
# ----------
# train Loss: 0.3157 Acc: 0.8663
# val Loss: 0.3089 Acc: 0.8776
#
# Epoch 12/19
# ----------
# train Loss: 0.3134 Acc: 0.8675
# val Loss: 0.2784 Acc: 0.8846
#
# Epoch 13/19
# ----------
# train Loss: 0.3104 Acc: 0.8689
# val Loss: 0.2855 Acc: 0.8787
#
# Epoch 14/19
# ----------
# train Loss: 0.3080 Acc: 0.8712
# val Loss: 0.2808 Acc: 0.8872
#
# Epoch 15/19
# ----------
# train Loss: 0.3079 Acc: 0.8696
# val Loss: 0.2792 Acc: 0.8855
#
# Epoch 16/19
# ----------
# train Loss: 0.3049 Acc: 0.8716
# val Loss: 0.2887 Acc: 0.8847
#
# Epoch 17/19
# ----------
# train Loss: 0.3004 Acc: 0.8728
# val Loss: 0.2894 Acc: 0.8824
#
# Epoch 18/19
# ----------
# train Loss: 0.3013 Acc: 0.8731
# val Loss: 0.2872 Acc: 0.8895
#
# Epoch 19/19
# ----------
# train Loss: 0.2990 Acc: 0.8745
# val Loss: 0.2977 Acc: 0.8849
#
# Training complete in 1245m 47s
# Best val Acc: 0.889503

# %%
# Plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.legend()

plt.show()

# %%
subset_indices_test = torch.randperm(len(image_datasets['test']))[:int(0.3*len(image_datasets['test']))]
test_data_subset = torch.utils.data.Subset(image_datasets['test'], subset_indices_test)
test_dataloader = torch.utils.data.DataLoader(test_data_subset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
def evaluate_model(model, dataloader):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)

            _, preds = torch.max(outputs, 1)
            running_corrects += torch.sum(preds == labels.data).item()

    loss = running_loss / len(dataloader.dataset)
    accuracy = running_corrects / len(dataloader.dataset)

    return loss, accuracy

test_loss, test_accuracy = evaluate_model(model, test_dataloader)

print('Test Loss: {:.4f}, Test Accuracy: {:.4f}'.format(test_loss, test_accuracy))
# Out:
# Test Loss: 0.2939, Test Accuracy: 0.8906

# %%
from sklearn.metrics import classification_report

def evaluate_model(model, dataloader, device):
    model.eval()
    y_pred = []
    y_true = []

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            y_pred.extend(preds.cpu().numpy())
            y_true.extend(labels.cpu().numpy())

    print(classification_report(y_true, y_pred))

# Assume 'device' is defined (e.g., device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
evaluate_model(model, test_dataloader, device)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92      5895
#            1       0.84      0.78      0.81      2432
#
#     accuracy                           0.89      8327
#    macro avg       0.87      0.86      0.86      8327
# weighted avg       0.89      0.89      0.89      8327

# %%
list_img_names = []

counter = 0
for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

    for j in range(inputs.size(0)):
        # Obtener el nombre de la imagen
        image_index = i * test_dataloader.batch_size + j
        image_path = test_data_subset.dataset.samples[image_index][0]
        image_name = os.path.basename(image_path)
        print("Nombre de la imagen: {}".format(image_name))
        list_img_names.append(image_name)
        # Loading and showing the image
        image = inputs[j].permute(1, 2, 0).cpu().numpy()

        # Normalizing the image
        image = (image - image.min()) / (image.max() - image.min())

        """
        plt.figure()
        plt.imshow(image)
        plt.axis('off')
        plt.show()
        """
        # Print the prediction and the correct label
        prediction = preds[j].item()
        correct_label = labels[j].item()
        print("Predicción: {}, Etiqueta correcta: {}".format(prediction, correct_label))
# Out:
# Nombre de la imagen: 10253_idx5_x1001_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1001_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1051_y1151_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1051_y151_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1101_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1101_y351_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1101_y851_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1201_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1251_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1251_y1201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1251_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1251_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1301_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1301_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1351_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1351_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1401_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1451_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1501_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1501_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1501_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1551_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1551_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1551_y1351_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1551_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x1651_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1651_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1701_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1801_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x1901_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x2001_y1251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x2001_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x2201_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x2301_y1201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x2551_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10253_idx5_x701_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x751_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x901_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x901_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10253_idx5_x901_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1001_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1001_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1001_y401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1001_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1001_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x101_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x101_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1051_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1051_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1051_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1101_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1101_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1101_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1201_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1201_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1251_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1251_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1251_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1251_y501_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1301_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1301_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1301_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1351_y1551_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1351_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1351_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1351_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1401_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1451_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1451_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1501_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1501_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x151_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1601_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1701_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x1801_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1801_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1851_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x1901_y701_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x201_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x201_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x201_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x201_y701_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x2051_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x2051_y701_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x2101_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x2101_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x2151_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x2201_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x2301_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x2351_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x2351_y551_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x251_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x251_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x251_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x301_y201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x301_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x301_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x351_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x351_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x351_y1651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x351_y1751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x501_y101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x501_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x551_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x551_y1401_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x601_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x601_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x651_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x651_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x701_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x701_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x701_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x701_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x751_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x751_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x751_y1651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x751_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x751_y51_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x751_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x801_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x851_y551_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10254_idx5_x851_y751_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x951_y101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x951_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10254_idx5_x951_y1601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10255_idx5_x1051_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1301_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1301_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10255_idx5_x1351_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1351_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1351_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1401_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1551_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1701_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x1751_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10255_idx5_x201_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x2151_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x2251_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10255_idx5_x651_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x651_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10255_idx5_x751_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1051_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1201_y851_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1201_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1251_y901_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1351_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1401_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1401_y1401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1451_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1451_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1451_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1501_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1501_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1551_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1551_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1601_y1251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1601_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1651_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1651_y601_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x1701_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1701_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1801_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1851_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1951_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x1951_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x2001_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x201_y601_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x2151_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x2151_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x2201_y351_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x351_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10256_idx5_x651_y551_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10256_idx5_x651_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1151_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1251_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1351_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1401_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1451_y1351_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1501_y651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x1651_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1651_y1951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1701_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x1701_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1701_y701_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x1751_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x1751_y701_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x1851_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1901_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x1951_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2001_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2001_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2001_y2101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2051_y101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x2051_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2101_y101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2101_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2101_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2101_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2151_y1951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2201_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2201_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2201_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2251_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2251_y201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10257_idx5_x2301_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2301_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2351_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x2351_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x501_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x501_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x601_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10257_idx5_x901_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x101_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1101_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1101_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1101_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x1251_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1351_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1351_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1351_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1401_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1451_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1451_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x1501_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1551_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1601_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x1601_y851_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x1651_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1801_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x1951_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x2001_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x2151_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x2151_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x2201_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x2201_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x2301_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x2401_y1501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x2401_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x451_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x551_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x701_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x701_y51_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x751_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x751_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x751_y251_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x751_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x751_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x751_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x801_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x801_y51_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10258_idx5_x851_y51_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10258_idx5_x951_y1151_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1001_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1001_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1001_y901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1001_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1051_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1101_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1201_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1201_y901_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1251_y851_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1301_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1301_y2001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1301_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1301_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1401_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1401_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1451_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1451_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1451_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1451_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1501_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1501_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x151_y1151_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x151_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1551_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1551_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1551_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1601_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1601_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1601_y2001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1601_y951_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1651_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1651_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1651_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1651_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1651_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1701_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1701_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1701_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1701_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1751_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1751_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1751_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1801_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1801_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1801_y1201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1851_y1251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1851_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1851_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1851_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1851_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1851_y351_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1851_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1851_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1901_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1901_y601_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1951_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1951_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1951_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1951_y1951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x1951_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1951_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x1951_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2001_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2001_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2001_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2001_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x201_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2051_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2051_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2051_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2101_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2151_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2201_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2201_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2251_y1851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2251_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2301_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2301_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2351_y101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2351_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2351_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2351_y51_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2351_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2401_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2401_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2451_y101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2451_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2451_y1201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2451_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2451_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2451_y401_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2501_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2551_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2551_y1351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2601_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2601_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2601_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2601_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2651_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2651_y401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2701_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2701_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2701_y601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2701_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2751_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2751_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2751_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2751_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2801_y1501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2801_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2851_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2851_y1151_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2851_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2851_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2851_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2851_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2901_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2901_y1451_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2901_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2901_y901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x2901_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x2951_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x3001_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x301_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x301_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x301_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x351_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x351_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x401_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x401_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x451_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x51_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x551_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x551_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x651_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x701_y1001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x701_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x701_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x701_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x701_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x751_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x751_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x751_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x801_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x851_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10259_idx5_x901_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x901_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x901_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x901_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x901_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10259_idx5_x951_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1001_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x101_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1051_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1101_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1101_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1101_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1151_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1151_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1201_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1201_y351_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1251_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1301_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1351_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1401_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1451_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1451_y451_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1501_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x151_y1151_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x151_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x151_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1551_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1651_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1651_y251_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1751_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1801_y1401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1801_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1851_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1851_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1851_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1901_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1901_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1901_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1951_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x1951_y601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1951_y751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x1951_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2001_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2001_y401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2001_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2001_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x201_y1701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x201_y751_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2051_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2051_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2051_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2051_y601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2101_y501_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2101_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2151_y651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2151_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2201_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2251_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2251_y1301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2251_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2301_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2301_y1201_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2301_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2301_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2351_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2351_y401_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2401_y1651_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2401_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2451_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2451_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2451_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2451_y1651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2451_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2501_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2501_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2501_y901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x251_y1751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x251_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2551_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2551_y451_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2601_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2651_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2701_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2751_y651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x2751_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x2751_y951_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x301_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x351_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x351_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x401_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x401_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x451_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x501_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x501_y1251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x551_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x551_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x551_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x601_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x601_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x651_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x651_y751_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x701_y301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x701_y651_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x701_y901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x701_y951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x751_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x751_y1651_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10260_idx5_x801_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x901_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x901_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x901_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10260_idx5_x951_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1001_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1051_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1051_y301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1101_y251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1201_y101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1201_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1301_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1351_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1351_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1351_y551_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1451_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1451_y201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1451_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1501_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1551_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1551_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1551_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1601_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1601_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1651_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1651_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 10261_idx5_x1701_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 10261_idx5_x1801_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# ...
# Nombre de la imagen: 12954_idx5_x2001_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2001_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2001_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2001_y2251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2001_y2951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x201_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2051_y2501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2051_y2801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2051_y2951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2051_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2101_y1951_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y2501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y2951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2101_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2151_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2151_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2151_y1601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2151_y2451_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2151_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2201_y1401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2201_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2201_y2351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2201_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2251_y1101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2251_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2251_y2301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2251_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2251_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2251_y851_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2301_y1601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2301_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2301_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2351_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2351_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2351_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2351_y351_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2351_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2401_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2401_y2351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2401_y501_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2451_y1101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2451_y1551_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2451_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2501_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2501_y2751_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2501_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2501_y901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2551_y2151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2551_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2551_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2601_y2401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2601_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2651_y2401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2651_y401_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2651_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2651_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2701_y2101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2751_y2101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2751_y2951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2801_y151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2801_y2151_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2801_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2801_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2801_y951_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2851_y2201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2901_y2051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2901_y2101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2901_y251_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2901_y901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x2951_y251_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x2951_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x3001_y101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3001_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x3051_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x3101_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x3201_y2951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3251_y51_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3301_y2951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3401_y2951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3501_y251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x351_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x3601_y451_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x3801_y2951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x401_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x401_y751_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x451_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x451_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x501_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x501_y1251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x501_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x501_y351_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x501_y601_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x501_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x551_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x601_y1401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x601_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x601_y701_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x651_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x651_y751_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x701_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x751_y1451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x751_y851_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x801_y1051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x801_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x801_y651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x801_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x851_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x851_y2951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x851_y451_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x851_y501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x851_y851_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x901_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x901_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x951_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x951_y1151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12954_idx5_x951_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x951_y2951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12954_idx5_x951_y801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1001_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x101_y2101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1051_y551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1051_y801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1101_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1101_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1201_y1351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1201_y1951_class0.png
# Predicción: 0, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1201_y601_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1251_y2301_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1301_y1301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1301_y2001_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1301_y2051_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1301_y2101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1351_y1501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1351_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1351_y2001_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1351_y2151_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1351_y2251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1351_y2301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1401_y1651_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1401_y2401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1451_y2301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x151_y2051_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1551_y1201_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1551_y1951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1551_y2101_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1551_y2401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1601_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1601_y2251_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1601_y2501_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1651_y1051_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1701_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1701_y501_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1751_y1901_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x1901_y1801_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x1951_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2001_y2001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2051_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2051_y401_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2101_y951_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2151_y1001_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2151_y2101_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x2401_y301_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2451_y701_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x2501_y1901_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x2501_y1951_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x2801_y1551_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x2951_y1551_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x401_y1801_class0.png
# Predicción: 1, Etiqueta correcta: 1
# Nombre de la imagen: 12955_idx5_x401_y351_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x401_y451_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x401_y701_class0.png
# Predicción: 0, Etiqueta correcta: 0
# Nombre de la imagen: 12955_idx5_x451_y1551_class0.png
# Predicción: 1, Etiqueta correcta: 0

# %%
patient_ids = []
for name in list_img_names:
    id = name.split('_')[0]
    patient_ids.append(id)

# %%
ids_unique = list(set(patient_ids))

# %%
base_path = main_folder

# %%
def get_cancer_dataframe(patient_id, cancer_id):
    path = os.path.join(base_path, patient_id, cancer_id)
    files = os.listdir(path)
    dataframe = pd.DataFrame(files, columns=["filename"])
    path_names = [os.path.join(path, filename) for filename in dataframe.filename.values]
    dataframe = dataframe.filename.str.rsplit("_", n=4, expand=True)
    dataframe.loc[:, "target"] = np.int(cancer_id)
    dataframe.loc[:, "path"] = path_names
    dataframe = dataframe.drop([0, 1, 4], axis=1)
    dataframe = dataframe.rename({2: "x", 3: "y"}, axis=1)
    dataframe.loc[:, "x"] = dataframe.loc[:,"x"].str.replace("x", "", case=False).astype(np.int)
    dataframe.loc[:, "y"] = dataframe.loc[:,"y"].str.replace("y", "", case=False).astype(np.int)
    return dataframe

def get_patient_dataframe(patient_id):
    df_0 = get_cancer_dataframe(patient_id, "0")
    df_1 = get_cancer_dataframe(patient_id, "1")
    patient_df = pd.concat([df_0, df_1], ignore_index=True)
    return patient_df

# %%
def visualise_breast_tissue_base(patient_id, pred_df=None):
    example_df = get_patient_dataframe(patient_id)
    max_point = [example_df.y.max()-1, example_df.x.max()-1]
    grid = 255*np.ones(shape=(max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)
    mask = 255*np.ones(shape=(max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)
    if pred_df is not None:
        patient_df = pred_df[pred_df.patient_id == patient_id].copy()
    mask_proba = np.zeros(shape=(max_point[0] + 50, max_point[1] + 50, 1)).astype(np.float)
    
    broken_patches = []
    for n in range(len(example_df)):
        try:
            image = imread(example_df.path.values[n])
            target = example_df.target.values[n]
            x_coord = np.int(example_df.x.values[n])
            y_coord = np.int(example_df.y.values[n])
            x_start = x_coord - 1
            y_start = y_coord - 1
            x_end = x_start + 50
            y_end = y_start + 50

            grid[y_start:y_end, x_start:x_end] = image
            if target == 1:
                mask[y_start:y_end, x_start:x_end, 0] = 250
                mask[y_start:y_end, x_start:x_end, 1] = 0
                mask[y_start:y_end, x_start:x_end, 2] = 0
            if pred_df is not None:
                proba = patient_df[(patient_df.x==x_coord) & (patient_df.y==y_coord)].proba
                mask_proba[y_start:y_end, x_start:x_end, 0] = np.float(proba)

        except ValueError:
            broken_patches.append(example_df.path.values[n])
    
    return grid, mask, broken_patches, mask_proba

# %%
def visualise_breast_tissue(patient_id):
    grid, mask, broken_patches,_ = visualise_breast_tissue_base(patient_id)

    fig, ax = plt.subplots(1,2,figsize=(20,10))
    ax[0].imshow(grid, alpha=0.9)
    ax[1].imshow(mask, alpha=0.8)
    ax[1].imshow(grid, alpha=0.7)
    ax[0].grid(False)
    ax[1].grid(False)
    for m in range(2):
        ax[m].set_xlabel("X-coord")
        ax[m].set_ylabel("Y-coord")
    ax[0].set_title("Breast tissue slice of patient: " + patient_id)
    ax[1].set_title("Cancer tissue colored red \n of patient: " + patient_id)

    plt.show()

# %%
def visualise_breast_tissue_binary(patient_id):
        
    fig, ax = plt.subplots(1, 1)

    example_df = get_patient_dataframe(patient_id)

    ax.scatter(example_df.x.values, example_df.y.values, c=example_df.target.values, cmap="coolwarm", s=20)
    ax.set_title("Patient " + patient_id)
    ax.set_xlabel("X coord")
    ax.set_ylabel("Y coord")
    ax.set_aspect('equal')  # Set aspect ratio to 'equal' to preserve original orientation
    ax.invert_yaxis()  # Reverse the y-axis direction

    plt.show()

# %%
# Obtener 5 elementos aleatorios de la lista
random_patient_ids = random.sample(patient_ids, k=5)

# %%
for id in random_patient_ids: #ids_unique:
    print("Patient's ID: ", id)
    visualise_breast_tissue(id)
    visualise_breast_tissue_binary(id)
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for id in random_patient_ids: #ids_unique:
#       2     print("Patient's ID: ", id)
#       3     visualise_breast_tissue(id)
#
# NameError: name 'random_patient_ids' is not defined
